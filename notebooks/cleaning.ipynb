# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
data = pd.read_csv("../data/student_habits_performance.csv")
data.head()
# Out:
#   student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0      S1000   23  Female                  0.0                 1.2
# 1      S1001   20  Female                  6.9                 2.8
# 2      S1002   21    Male                  1.4                 3.1
# 3      S1003   23  Female                  1.0                 3.9
# 4      S1004   19  Female                  5.0                 4.4
#
#    netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# 0            1.1            No                   85.0          8.0
# 1            2.3            No                   97.3          4.6
# 2            1.3            No                   94.8          8.0
# 3            1.0            No                   71.0          9.2
# 4            0.5            No                   90.9          4.9
#
#   diet_quality  exercise_frequency parental_education_level internet_quality  \
# 0         Fair                   6                   Master          Average
# 1         Good                   6              High School          Average
# 2         Poor                   1              High School             Poor
# 3         Poor                   4                   Master             Good
# 4         Fair                   3                   Master             Good
#
#    mental_health_rating extracurricular_participation  exam_score
# 0                     8                           Yes        56.2
# 1                     8                            No       100.0
# 2                     1                            No        34.3
# 3                     1                           Yes        26.8
# 4                     1                            No        66.4

# %%
duplicate_count = data.duplicated().sum()
if duplicate_count > 0:
    data = data.drop_duplicates()
    print(f"Removed {duplicate_count} duplicate rows.")
else:
    print("No duplicate rows found.")
# Out:
# No duplicate rows found.

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   student_id                     1000 non-null   str
#  1   age                            1000 non-null   int64
#  2   gender                         1000 non-null   str
#  3   study_hours_per_day            1000 non-null   float64
#  4   social_media_hours             1000 non-null   float64
#  5   netflix_hours                  1000 non-null   float64
#  6   part_time_job                  1000 non-null   str
#  7   attendance_percentage          1000 non-null   float64
#  8   sleep_hours                    1000 non-null   float64
#  9   diet_quality                   1000 non-null   str
#  10  exercise_frequency             1000 non-null   int64
#  11  parental_education_level       909 non-null    str
#  12  internet_quality               1000 non-null   str
#  13  mental_health_rating           1000 non-null   int64
#  14  extracurricular_participation  1000 non-null   str
#  15  exam_score                     1000 non-null   float64
# dtypes: float64(6), int64(3), str(7)
# memory usage: 125.1 KB

# %%
data.isnull().sum()
# Out:
# student_id                        0
# age                               0
# gender                            0
# study_hours_per_day               0
# social_media_hours                0
# netflix_hours                     0
# part_time_job                     0
# attendance_percentage             0
# sleep_hours                       0
# diet_quality                      0
# exercise_frequency                0
# parental_education_level         91
# internet_quality                  0
# mental_health_rating              0
# extracurricular_participation     0
# exam_score                        0
# dtype: int64

# %%
if data['parental_education_level'].isnull().any():
    data['parental_education_level'] = data['parental_education_level'].fillna('Unknown')
    print("Filled missing values in 'parental_education_level' with 'Unknown'.")
else:
    print("No missing values in 'parental_education_level'.")
# Out:
# Filled missing values in 'parental_education_level' with 'Unknown'.

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   student_id                     1000 non-null   str
#  1   age                            1000 non-null   int64
#  2   gender                         1000 non-null   str
#  3   study_hours_per_day            1000 non-null   float64
#  4   social_media_hours             1000 non-null   float64
#  5   netflix_hours                  1000 non-null   float64
#  6   part_time_job                  1000 non-null   str
#  7   attendance_percentage          1000 non-null   float64
#  8   sleep_hours                    1000 non-null   float64
#  9   diet_quality                   1000 non-null   str
#  10  exercise_frequency             1000 non-null   int64
#  11  parental_education_level       1000 non-null   str
#  12  internet_quality               1000 non-null   str
#  13  mental_health_rating           1000 non-null   int64
#  14  extracurricular_participation  1000 non-null   str
#  15  exam_score                     1000 non-null   float64
# dtypes: float64(6), int64(3), str(7)
# memory usage: 125.1 KB

# %%
data['parental_education_level'].value_counts()
# Out:
# parental_education_level
# High School    392
# Bachelor       350
# Master         167
# Unknown         91
# Name: count, dtype: int64

# %%
data.head().T
# Out:
#                                      0            1            2       3  \
# student_id                       S1000        S1001        S1002   S1003
# age                                 23           20           21      23
# gender                          Female       Female         Male  Female
# study_hours_per_day                0.0          6.9          1.4     1.0
# social_media_hours                 1.2          2.8          3.1     3.9
# netflix_hours                      1.1          2.3          1.3     1.0
# part_time_job                       No           No           No      No
# attendance_percentage             85.0         97.3         94.8    71.0
# sleep_hours                        8.0          4.6          8.0     9.2
# diet_quality                      Fair         Good         Poor    Poor
# exercise_frequency                   6            6            1       4
# parental_education_level        Master  High School  High School  Master
# internet_quality               Average      Average         Poor    Good
# mental_health_rating                 8            8            1       1
# extracurricular_participation      Yes           No           No     Yes
# exam_score                        56.2        100.0         34.3    26.8
#
#                                     4
# student_id                      S1004
# age                                19
# gender                         Female
# study_hours_per_day               5.0
# social_media_hours                4.4
# netflix_hours                     0.5
# part_time_job                      No
# attendance_percentage            90.9
# sleep_hours                       4.9
# diet_quality                     Fair
# exercise_frequency                  3
# parental_education_level       Master
# internet_quality                 Good
# mental_health_rating                1
# extracurricular_participation      No
# exam_score                       66.4

# %%
numeric_columns = data.select_dtypes(include=[np.number]).columns.tolist()
print("Numeric columns in the dataset:", numeric_columns)
# Out:
# Numeric columns in the dataset: ['age', 'study_hours_per_day', 'social_media_hours', 'netflix_hours', 'attendance_percentage', 'sleep_hours', 'exercise_frequency', 'mental_health_rating', 'exam_score']

# %%
def find_outliers(data, col):
    Q1 = data[col].quantile(0.25)
    Q3 = data[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = data[(data[col] < lower_bound) | (data[col] > upper_bound)]
    return outliers, lower_bound, upper_bound

outlier_summary = []


for col in numeric_columns:
    outliers, lower, upper = find_outliers(data, col)
    outlier_summary.append({
        'Column': col,
        "Outlier Count": outliers.shape[0],
        'Lower Bound': lower,
        'Upper Bound': upper,
        "min_value": data[col].min(),
        "max_value": data[col].max()
    })

outlier_df = pd.DataFrame(outlier_summary)
outlier_df
# Out:
#                   Column  Outlier Count  Lower Bound  Upper Bound  min_value  \
# 0                    age              0      12.3750      29.3750       17.0
# 1    study_hours_per_day              7      -0.2500       7.3500        0.0
# 2     social_media_hours              5      -0.7000       5.7000        0.0
# 3          netflix_hours              4      -1.2875       4.8125        0.0
# 4  attendance_percentage              3      58.4625     110.5625       56.0
# 5            sleep_hours              2       3.0500       9.8500        3.2
# 6     exercise_frequency              0      -5.0000      11.0000        0.0
# 7   mental_health_rating              0      -4.5000      15.5000        1.0
# 8             exam_score              2      24.2000     115.6000       18.4
#
#    max_value
# 0       24.0
# 1        8.3
# 2        7.2
# 3        5.4
# 4      100.0
# 5       10.0
# 6        6.0
# 7       10.0
# 8      100.0

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import logging


logger = logging.getLogger(__name__)
data = pd.read_csv("../data/student_habits_performance.csv")

def clean_data(data: pd.DataFrame) -> pd.DataFrame:
    # Create a copy so we don't modify the original unintentionally
    cleaned_data = data.copy()

    # Remove duplicates
    duplicate_count = cleaned_data.duplicated().sum()
    if duplicate_count > 0:
        cleaned_data = cleaned_data.drop_duplicates()
        logger.info(f"Removed {duplicate_count} duplicate rows.")
    else:
        logger.info("No duplicate rows found.")

    # Handle missing values
    if cleaned_data['parental_education_level'].isnull().any():
        cleaned_data['parental_education_level'] = cleaned_data['parental_education_level'].fillna('Unknown')
        logger.info("Filled missing values in 'parental_education_level' with 'Unknown'.")
    else:
        logger.info("No missing values in 'parental_education_level'.")

    remaning_null = cleaned_data.isnull().sum().sum()
    if remaning_null > 0:
        logger.warning(f"There are still {remaning_null} missing values in the dataset.")
    else:
        logger.info("No missing values remain in the dataset.")

    return cleaned_data


if __name__ == "__main__":
    cleaned_data = clean_data(data)
    print(cleaned_data.info())
    print("Duplicate Count:", duplicate_count)
    print("Remaining Missing Values:", cleaned_data.isnull().sum().sum())
    print(cleaned_data.shape)
    print(cleaned_data['parental_education_level'].value_counts())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   student_id                     1000 non-null   str
#  1   age                            1000 non-null   int64
#  2   gender                         1000 non-null   str
#  3   study_hours_per_day            1000 non-null   float64
#  4   social_media_hours             1000 non-null   float64
#  5   netflix_hours                  1000 non-null   float64
#  6   part_time_job                  1000 non-null   str
#  7   attendance_percentage          1000 non-null   float64
#  8   sleep_hours                    1000 non-null   float64
#  9   diet_quality                   1000 non-null   str
#  10  exercise_frequency             1000 non-null   int64
#  11  parental_education_level       1000 non-null   str
#  12  internet_quality               1000 non-null   str
#  13  mental_health_rating           1000 non-null   int64
#  14  extracurricular_participation  1000 non-null   str
#  15  exam_score                     1000 non-null   float64
# dtypes: float64(6), int64(3), str(7)
# memory usage: 125.1 KB
# None
# Duplicate Count: 0
# Remaining Missing Values: 0
# (1000, 16)
# parental_education_level
# High School    392
# Bachelor       350
# Master         167
# Unknown         91
# Name: count, dtype: int64
